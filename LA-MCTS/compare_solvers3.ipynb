# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
def get_dataframe(filename):
    data = pd.read_json(filename, lines=True)
    melted_df = data.melt()
    return melted_df

# %% [markdown]
# ## Ackley best number of samples PSO

# %%
ackley_pso_10 = get_dataframe('results/cluster_results/Ackley20_pso_10samples/result3000')
ackley_pso_25 = get_dataframe('results/cluster_results/Ackley20_pso_25samples/result3000')
ackley_pso_50 = get_dataframe('results/cluster_results/Ackley20_pso_50samples/result3000')
ackley_pso_75 = get_dataframe('results/cluster_results/Ackley20_pso_75samples/result3000')


sns.lineplot(data=ackley_pso_10, x='variable', y='value', label='Ackley PSO 10')
sns.lineplot(data=ackley_pso_25, x='variable', y='value', label='Ackley PSO 25')
sns.lineplot(data=ackley_pso_50, x='variable', y='value', label='Ackley PSO 50')
sns.lineplot(data=ackley_pso_75, x='variable', y='value', label='Ackley PSO 75')

plt.title("Sampling PSO [ackley]")
plt.show()

# %%
sns.lineplot(data=ackley_pso_10, x='variable', y='value', label='Ackley PSO 10')
sns.lineplot(data=ackley_pso_25, x='variable', y='value', label='Ackley PSO 25')
sns.lineplot(data=ackley_pso_50, x='variable', y='value', label='Ackley PSO 50')
sns.lineplot(data=ackley_pso_75, x='variable', y='value', label='Ackley PSO 75')

plt.title("Sampling PSO [ackley - log scale]")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Ackley best number of samples BO

# %%
ackley_bo_1 = get_dataframe('results/cluster_results/Ackley20_bo_1samples/result800')
ackley_bo_10 = get_dataframe('results/cluster_results/Ackley20_bo_10samples/result1500')
ackley_bo_100 = get_dataframe('results/cluster_results/Ackley20_bo_100samples/result1500')


sns.lineplot(data=ackley_bo_1, x='variable', y='value', label='ackley BO 1')
sns.lineplot(data=ackley_bo_10, x='variable', y='value', label='ackley BO 10')
sns.lineplot(data=ackley_bo_100, x='variable', y='value', label='ackley BO 100')

plt.title("Sampling BO [ackley]")
plt.show()

# %% [markdown]
# ## Ackley best number of samples TuRBO

# %%
ackley_turbo_100 = get_dataframe('results/cluster_results/Ackley20_turbo_100max_samples/result1500')
ackley_turbo_1000 = get_dataframe('results/cluster_results/Ackley20_turbo_1000max_samples/result1000')
ackley_turbo_10000 = get_dataframe('results/cluster_results/Ackley20_turbo_10000max_samples/result800')


sns.lineplot(data=ackley_turbo_100, x='variable', y='value', label='ackley TuRBO 100')
sns.lineplot(data=ackley_turbo_1000, x='variable', y='value', label='ackley TuRBO 1000')
sns.lineplot(data=ackley_turbo_10000, x='variable', y='value', label='ackley TuRBO 10000')

plt.title("Sampling TuRBO [ackley]")
plt.show()

# %%
sns.lineplot(data=ackley_turbo_100, x='variable', y='value', label='ackley TuRBO 100')
sns.lineplot(data=ackley_turbo_1000, x='variable', y='value', label='ackley TuRBO 1000')
sns.lineplot(data=ackley_turbo_10000, x='variable', y='value', label='ackley TuRBO 10000')

plt.title("Sampling TuRBO [ackley - log scale]")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Ackley compare BB optimizers

# %%
sns.lineplot(data=ackley_bo_1, x='variable', y='value', label='ackley BO')
sns.lineplot(data=ackley_turbo_10000, x='variable', y='value', label='ackley TuRBO')
# sns.lineplot(data=ackley_de_rand_10, x='variable', y='value', label='ackley DE/rand')
# sns.lineplot(data=ackley_de_best_75, x='variable', y='value', label='ackley DE/best')
sns.lineplot(data=ackley_pso_10, x='variable', y='value', label='ackley PSO')


plt.title("Compare BB optimizers [ackley]")
plt.show()

# %% [markdown]
# # hGRNs

# %% [markdown]
# ## testHGRN best number of samples DE/rand

# %%
rand_1 = get_dataframe('results/cluster_results/testHgrn_de_rand_1samples_crit3/result3500')
rand_10 = get_dataframe('results/cluster_results/testHgrn_de_rand_10samples_crit3/result3500')
rand_100 = get_dataframe('results/cluster_results/testHgrn_de_rand_100samples_crit3/result3500')


sns.lineplot(data=rand_1, x='variable', y='value', label='hGRN DE rand 1')
sns.lineplot(data=rand_10, x='variable', y='value', label='hGRN DE rand 10')
sns.lineplot(data=rand_100, x='variable', y='value', label='hGRN DE rand 100')

plt.title("testHGRN - sampling DE/rand")
plt.show()

# %%
sns.lineplot(data=rand_1, x='variable', y='value', label='LA-MCTS (DE rand 1)')
sns.lineplot(data=rand_10, x='variable', y='value', label='LA-MCTS (DE rand 10)')
sns.lineplot(data=rand_100, x='variable', y='value', label='LA-MCTS (DE rand 100)')

plt.title("testHGRN - sampling DE/rand [log scale]")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## testHGR best number of samples DE/best

# %%
best_1 = get_dataframe('results/cluster_results/testHgrn_de_best_1samples_crit3/result3500')
best_10 = get_dataframe('results/cluster_results/testHgrn_de_best_10samples_crit3/result3500')
best_100 = get_dataframe('results/cluster_results/testHgrn_de_best_100samples_crit3/result3500')

sns.lineplot(data=best_1, x='variable', y='value', label='LA-MCTS (DE best 1)')
sns.lineplot(data=best_10, x='variable', y='value', label='LA-MCTS (DE best 10)')
sns.lineplot(data=best_100, x='variable', y='value', label='LA-MCTS (DE best 100)')

plt.title("testHGRN - sampling DE/best")
plt.show()

# %%
sns.lineplot(data=best_1, x='variable', y='value', label='LA-MCTS (DE best 1)')
sns.lineplot(data=best_10, x='variable', y='value', label='LA-MCTS (DE best 10)')
sns.lineplot(data=best_100, x='variable', y='value', label='LA-MCTS (DE best 100)')

plt.title("testHGRN - sampling DE/best [log scale]")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## testHGRN Best number of samples PSO

# %%
pso_1 = get_dataframe('results/cluster_results/testHgrn_pso_1samples_crit3/result3500')
pso_10 = get_dataframe('results/cluster_results/testHgrn_pso_10samples_crit3/result3500')
pso_100 = get_dataframe('results/cluster_results/testHgrn_pso_100samples_crit3/result3500')

sns.lineplot(data=pso_1, x='variable', y='value', label='LA-MCTS (DE pso 1)')
sns.lineplot(data=pso_10, x='variable', y='value', label='LA-MCTS (DE pso 10)')
sns.lineplot(data=pso_100, x='variable', y='value', label='LA-MCTS (DE pso 100)')

plt.title("testHGRN - sampling PSO")
plt.show()

# %%
sns.lineplot(data=pso_1, x='variable', y='value', label='LA-MCTS (DE pso 1)')
sns.lineplot(data=pso_10, x='variable', y='value', label='LA-MCTS (DE pso 10)')
sns.lineplot(data=pso_100, x='variable', y='value', label='LA-MCTS (DE pso 100)')

plt.title("Sampling PSO [log scale]")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## testHGRN - BB optimizer comparison

# %%
hgrn_bo = get_dataframe('results/cluster_results/testHgrn_bo_1samples_crit3/result3500')
hgrn_turbo = get_dataframe('results/cluster_results/testHgrn_turbo_10000max_samples_crit3/result7500')
hgrn_de_rand = get_dataframe('results/cluster_results/testHgrn_de_rand_10samples_crit3/result7500')
hgrn_de_best = get_dataframe('results/cluster_results/testHgrn_de_best_10samples_crit3/result7500')
hgrn_pso = get_dataframe('results/cluster_results/testHgrn_pso_10samples_crit3/result35000')

sns.lineplot(data=hgrn_bo, x='variable', y='value', label='testhGRN bo')
sns.lineplot(data=hgrn_turbo, x='variable', y='value', label='testhGRN turbo')
sns.lineplot(data=hgrn_de_rand, x='variable', y='value', label='testhGRN de_rand')
sns.lineplot(data=hgrn_de_best, x='variable', y='value', label='testhGRN de_best')
sns.lineplot(data=hgrn_pso, x='variable', y='value', label='testhGRN pso')


plt.title("BB optimizers [test hGRN]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=hgrn_bo, x='variable', y='value', label='testhGRN bo')
sns.lineplot(data=hgrn_turbo, x='variable', y='value', label='testhGRN turbo')
sns.lineplot(data=hgrn_de_rand, x='variable', y='value', label='testhGRN de_rand')
sns.lineplot(data=hgrn_de_best, x='variable', y='value', label='testhGRN de_best')
sns.lineplot(data=hgrn_pso, x='variable', y='value', label='testhGRN pso')


plt.title("BB optimizers [test hGRN - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## circadian clock - best # samples DE/rand

# %%
circ_rand_1 = get_dataframe('results/cluster_results/circadianClock_de_rand_1samples_crit3/result3500')
circ_rand_10 = get_dataframe('results/cluster_results/circadianClock_de_rand_10samples_crit3/result3500')
circ_rand_100 = get_dataframe('results/cluster_results/circadianClock_de_rand_100samples_crit3/result3500')


sns.lineplot(data=circ_rand_1, x='variable', y='value', label='circadian DE rand 1')
sns.lineplot(data=circ_rand_10, x='variable', y='value', label='circadian DE rand 10')
sns.lineplot(data=circ_rand_100, x='variable', y='value', label='circadian DE rand 100')

plt.title("Sampling DE/rand [circadian cycle]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=circ_rand_1, x='variable', y='value', label='circadian DE rand 1')
sns.lineplot(data=circ_rand_10, x='variable', y='value', label='circadian DE rand 10')
sns.lineplot(data=circ_rand_100, x='variable', y='value', label='circadian DE rand 100')

plt.title("Sampling DE/rand [circadian clock - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## circadian clock - best # samples DE/best

# %%
circ_best_1 = get_dataframe('results/cluster_results/circadianClock_de_best_1samples_crit3/result20000')
circ_best_10 = get_dataframe('results/cluster_results/circadianClock_de_best_10samples_crit3/result20000')
circ_best_100 = get_dataframe('results/cluster_results/circadianClock_de_best_100samples_crit3/result15000')


sns.lineplot(data=circ_best_1, x='variable', y='value', label='circadian DE best 1')
sns.lineplot(data=circ_best_10, x='variable', y='value', label='circadian DE best 10')
sns.lineplot(data=circ_best_100, x='variable', y='value', label='circadian DE best 100')

plt.title("Sampling DE/best [circadian clock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=circ_best_1, x='variable', y='value', label='circadian DE best 1')
sns.lineplot(data=circ_best_10, x='variable', y='value', label='circadian DE best 10')
sns.lineplot(data=circ_best_100, x='variable', y='value', label='circadian DE best 100')

plt.title("Sampling DE/best [circadian cycle - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## circadian clock - best # samples PSO

# %%
circ_pso_1 = get_dataframe('results/cluster_results/circadianClock_pso_1samples_crit3/result15000')
circ_pso_10 = get_dataframe('results/cluster_results/circadianClock_pso_10samples_crit3/result15000')
circ_pso_100 = get_dataframe('results/cluster_results/circadianClock_pso_100samples_crit3/result15000')


sns.lineplot(data=circ_pso_1, x='variable', y='value', label='circadian PSO 1')
sns.lineplot(data=circ_pso_10, x='variable', y='value', label='circadian PSO 10')
sns.lineplot(data=circ_pso_100, x='variable', y='value', label='circadian PSO 100')

plt.title("Sampling PSO [circadian clock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=circ_pso_1, x='variable', y='value', label='circadian PSO 1')
sns.lineplot(data=circ_pso_10, x='variable', y='value', label='circadian PSO 10')
sns.lineplot(data=circ_pso_100, x='variable', y='value', label='circadian PSO 100')

plt.title("Sampling PSO [circadian cycle - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## circadian clock - BB optimizer comparison

# %%
circ_bo = get_dataframe('results/cluster_results/circadianClock_bo_1samples_crit3/result2000')
circ_turbo = get_dataframe('results/cluster_results/circadianClock_turbo_10000max_samples_crit3/result10000')
circ_de_rand = get_dataframe('results/cluster_results/circadianClock_de_rand_1samples_crit3/result4500')
circ_de_best = get_dataframe('results/cluster_results/circadianClock_de_best_1samples_crit3/result35000')
circ_pso = get_dataframe('results/cluster_results/circadianClock_pso_10samples_crit3/result15000')
circ_pso100 = get_dataframe('results/cluster_results/circadianClock_pso_10samples_crit3/result15000')

sns.lineplot(data=circ_bo, x='variable', y='value', label='circadian bo')
sns.lineplot(data=circ_turbo, x='variable', y='value', label='circadian turbo')
sns.lineplot(data=circ_de_rand, x='variable', y='value', label='circadian de_rand')
sns.lineplot(data=circ_de_best, x='variable', y='value', label='circadian de_best')
sns.lineplot(data=circ_pso, x='variable', y='value', label='circadian pso')


plt.title("BB optimizers [circadian clock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## cell cycle - sampling DE/rand

# %%
cell_rand_1 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_rand_1samples_crit3/result3000')
cell_rand_10 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_rand_10samples_crit3/result3000')
cell_rand_100 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_rand_100samples_crit3/result3000')


sns.lineplot(data=cell_rand_1, x='variable', y='value', label='cell cycle DE rand 1')
sns.lineplot(data=cell_rand_10, x='variable', y='value', label='cell cycle DE rand 10')
sns.lineplot(data=cell_rand_100, x='variable', y='value', label='cell cycle DE rand 100')

plt.title("Sampling DE/rand [cell cycle]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=cell_rand_1, x='variable', y='value', label='cell cycle DE rand 1')
sns.lineplot(data=cell_rand_10, x='variable', y='value', label='cell cycle DE rand 10')
sns.lineplot(data=cell_rand_100, x='variable', y='value', label='cell cycle DE rand 100')

plt.title("Sampling DE/rand [cell cycle - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## cell cycle - sampling DE/best

# %%
cell_best_1 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_best_1samples_crit3/result10000')
cell_best_10 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_best_10samples_crit3/result10000')
cell_best_100 = get_dataframe('results/cluster_results/cellCycleBehaegel_de_best_100samples_crit3/result5000')


sns.lineplot(data=cell_best_1, x='variable', y='value', label='cell cycle DE best 1')
sns.lineplot(data=cell_best_10, x='variable', y='value', label='cell cycle DE best 10')
sns.lineplot(data=cell_best_100, x='variable', y='value', label='cell cycle DE best 100')

plt.title("Sampling DE/best [cell cycle]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=cell_best_1, x='variable', y='value', label='cell cycle DE best 1')
sns.lineplot(data=cell_best_10, x='variable', y='value', label='cell cycle DE best 10')
sns.lineplot(data=cell_best_100, x='variable', y='value', label='cell cycle DE best 100')

plt.title("Sampling DE/best [cell cycle - log]")
plt.ylabel('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## cell cycle - sampling PSO

# %%
cell_pso_1 = get_dataframe('results/cluster_results/cellCycleBehaegel_pso_1samples_crit3/result15000')
cell_pso_10 = get_dataframe('results/cluster_results/cellCycleBehaegel_pso_10samples_crit3/result15000')
cell_pso_100 = get_dataframe('results/cluster_results/cellCycleBehaegel_pso_100samples_crit3/result15000')


sns.lineplot(data=cell_pso_1, x='variable', y='value', label='cell cycle PSO 1')
sns.lineplot(data=cell_pso_10, x='variable', y='value', label='cell cycle PSO 10')
sns.lineplot(data=cell_pso_100, x='variable', y='value', label='cell cycle PSO 100')

plt.title("Sampling PSO [cell cycle]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=cell_best_1, x='variable', y='value', label='cell cycle DE best 1')
sns.lineplot(data=cell_best_10, x='variable', y='value', label='cell cycle DE best 10')
sns.lineplot(data=cell_best_100, x='variable', y='value', label='cell cycle DE best 100')

plt.title("Sampling PSO [cell cycle]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## cell cycle - BB comparison

# %%
cell_bo = get_dataframe('results/cluster_results/cellCycleBehaegel_bo_1samples_crit3/result700')
cell_turbo = get_dataframe('results/cluster_results/cellCycleBehaegel_turbo_10000max_samples_crit3/result1000')
cell_best = cell_best_1
cell_rand = cell_rand_10
cell_pso = cell_pso_10



sns.lineplot(data=cell_bo, x='variable', y='value', label='cell cycle bo')
sns.lineplot(data=cell_turbo, x='variable', y='value', label='cell cycle turbo')
sns.lineplot(data=cell_best, x='variable', y='value', label='cell cycle de_rand')
sns.lineplot(data=cell_rand, x='variable', y='value', label='cell cycle de_best')
sns.lineplot(data=cell_pso, x='variable', y='value', label='cell cycle pso')


plt.title("BB optimizers [cell cycle]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# # Benchmark ROSENBROCK

# %% [markdown]
# ## Rosenbrock - sampling BO

# %%
rosenbrock_bo_1 = get_dataframe('results/cluster_results/Rosenbrock20_bo_1samples/result900')
rosenbrock_bo_10 = get_dataframe('results/cluster_results/Rosenbrock20_bo_10samples/result2000')
rosenbrock_bo_100 = get_dataframe('results/cluster_results/Rosenbrock20_bo_100samples/result2000')


sns.lineplot(data=rosenbrock_bo_1, x='variable', y='value', label='Rosenbrock BO 1')
sns.lineplot(data=rosenbrock_bo_10, x='variable', y='value', label='Rosenbrock BO 10')
sns.lineplot(data=rosenbrock_bo_100, x='variable', y='value', label='Rosenbrock BO 100')

plt.title("Sampling BO [rosenbrock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=rosenbrock_bo_1, x='variable', y='value', label='Rosenbrock BO 1')
sns.lineplot(data=rosenbrock_bo_10, x='variable', y='value', label='Rosenbrock BO 10')
sns.lineplot(data=rosenbrock_bo_100, x='variable', y='value', label='Rosenbrock BO 100')

plt.title("Sampling BO [rosenbrock - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## Rosenbrock - sampling TuRBO

# %%
rosenbrock_turbo_100 = get_dataframe('results/cluster_results/Rosenbrock20_turbo_100max_samples/result1000')
rosenbrock_turbo_1000 = get_dataframe('results/cluster_results/Rosenbrock20_turbo_1000max_samples/result1000')
rosenbrock_turbo_10000 = get_dataframe('results/cluster_results/Rosenbrock20_turbo_10000max_samples/result1000')


sns.lineplot(data=rosenbrock_turbo_100, x='variable', y='value', label='Rosenbrock TuRBO 100')
sns.lineplot(data=rosenbrock_turbo_1000, x='variable', y='value', label='Rosenbrock TuRBO 1000')
sns.lineplot(data=rosenbrock_turbo_10000, x='variable', y='value', label='Rosenbrock TuRBO 10000')

plt.title("Sampling TuRBO [rosenbrock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=rosenbrock_turbo_100, x='variable', y='value', label='Rosenbrock TuRBO 100')
sns.lineplot(data=rosenbrock_turbo_1000, x='variable', y='value', label='Rosenbrock TuRBO 1000')
sns.lineplot(data=rosenbrock_turbo_10000, x='variable', y='value', label='Rosenbrock TuRBO 10000')

plt.title("Sampling TuRBO [rosenbrock - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# ## Rosenbrock - bb optimizers

# %%
rosenbrock_bo = rosenbrock_bo_10
rosenbrock_turbo = rosenbrock_turbo_10000
rosenbrock_de_rand = get_dataframe('results/cluster_results/Rosenbrock20_de_rest_10samples/result6500')
rosenbrock_de_best = get_dataframe('results/cluster_results/Rosenbrock20_de_best_10samples/result3000')
rosenbrock_pso = get_dataframe('results/cluster_results/Rosenbrock20_pso_10samples/result7000')

sns.lineplot(data=rosenbrock_bo, x='variable', y='value', label='rosenbrock bo')
sns.lineplot(data=rosenbrock_turbo, x='variable', y='value', label='rosenbrock turbo')
sns.lineplot(data=rosenbrock_de_rand, x='variable', y='value', label='rosenbrock de_rand')
sns.lineplot(data=rosenbrock_de_best, x='variable', y='value', label='rosenbrock de_best')
sns.lineplot(data=rosenbrock_pso, x='variable', y='value', label='rosenbrock pso')


plt.title("BB optimizers [rosenbrock]")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %%
sns.lineplot(data=rosenbrock_bo, x='variable', y='value', label='rosenbrock bo')
sns.lineplot(data=rosenbrock_turbo, x='variable', y='value', label='rosenbrock turbo')
sns.lineplot(data=rosenbrock_de_rand, x='variable', y='value', label='rosenbrock de_rand')
sns.lineplot(data=rosenbrock_de_best, x='variable', y='value', label='rosenbrock de_best')
sns.lineplot(data=rosenbrock_pso, x='variable', y='value', label='rosenbrock pso')


plt.title("BB optimizers [rosenbrock - log scale]")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# # Compare paper Ackley

# %%
ackley_bo = ackley_bo_1
ackley_turbo = ackley_turbo_10000


sns.lineplot(data=ackley_bo, x='variable', y='value', label='ackley bo')
sns.lineplot(data=ackley_turbo, x='variable', y='value', label='ackley turbo')

plt.title("Ackley 20")
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()

# %% [markdown]
# # Compare paper Rosenbrock

# %%
rosenbrock_bo = rosenbrock_bo_1
rosenbrock_turbo = rosenbrock_turbo_10000


sns.lineplot(data=rosenbrock_bo, x='variable', y='value', label='rosenbrock bo')
sns.lineplot(data=rosenbrock_turbo, x='variable', y='value', label='rosenbrock turbo')

plt.title("Rosenbrock 20")
plt.yscale('log')
plt.ylabel('f(x)')
plt.xlabel('NFE')
plt.show()
