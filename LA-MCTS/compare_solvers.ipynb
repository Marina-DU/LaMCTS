# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
def get_dataframe(filename):
    data = pd.read_json(filename, lines=True)
    melted_df = data.melt()
    return melted_df

# %% [markdown]
# ## DE sampling from current samples or from new samples

# %%
de_best_100 = get_dataframe('results/Ackley2_de_best_100samples/result1000')
de_best_10 = get_dataframe('results/Ackley2_de_best_10samples/result1000')
de_best_1 = get_dataframe('results/Ackley2_de_best_1samples/result1000')
ackley_bo = get_dataframe('results/Ackley2_bo_1samples/result100')

sns.lineplot(data=de_best_100, x='variable', y='value', label='de_best_100')
sns.lineplot(data=de_best_10, x='variable', y='value', label='de_best_10')
sns.lineplot(data=de_best_1, x='variable', y='value', label='de_best_1')
sns.lineplot(data=ackley_bo, x='variable', y='value', label='ackley_bo')

plt.title("Sampling DE/rand [ackley]")
plt.yscale('log')
plt.show()

# %%
de_best_100 = get_dataframe('results/Ackley2_de_best_100samples/result1000')
de_best_10 = get_dataframe('results/Ackley2_de_best_10samples/result1000')
de_best_1 = get_dataframe('results/Ackley2_de_best_1samples/result1000')
ackley_bo = get_dataframe('results/Ackley2_bo_1samples/result100')

sns.lineplot(data=de_best_100, x='variable', y='value', label='de_best_100')
sns.lineplot(data=de_best_10, x='variable', y='value', label='de_best_10')
sns.lineplot(data=de_best_1, x='variable', y='value', label='de_best_1')
sns.lineplot(data=ackley_bo, x='variable', y='value', label='ackley_bo')

plt.title("Sampling DE/rand [ackley]")
plt.yscale('log')
plt.show()

# %%
de_rand_no = get_dataframe('results/Ackley2_de_rand_100samples/result1000_no')
de_rand = get_dataframe('results/Ackley2_de_rand_100samples/result1000')

sns.lineplot(data=de_rand_no, x='variable', y='value', label='100 no')
sns.lineplot(data=de_rand, x='variable', y='value', label='100')

plt.title("Sampling DE/rand [ackley]")
plt.yscale('log')
plt.show()
