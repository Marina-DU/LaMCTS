# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
def get_dataframe(filename):
    data = []
    with open(filename, 'r') as file:
        print(file)
        for line in file:
            data.append(json.loads(line))
    n_columns = len(data[0])
    data = pd.DataFrame(data, columns=list(range(1, n_columns + 1, 1)))
    melted_df = pd.melt(data)
    return melted_df

# %%
data_lamcts_de = get_dataframe('results/Ackleyde2/result200')
data_lamcts_turbo = get_dataframe('results/Ackleyturbo2/result200')
data_lamcts_bo = get_dataframe('results/Ackleybo2/result200')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Ackley2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Ackleyde2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleyturbo2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleybo2/result200' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de = get_dataframe('results/Rosenbrockde2/result200')
data_lamcts_turbo = get_dataframe('results/Rosenbrockturbo2/result200')
data_lamcts_bo = get_dataframe('results/Rosenbrockbo2/result200')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Rosenbrock2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Rosenbrockde2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockturbo2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockbo2/result200' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de = get_dataframe('results/Levyde2/result200')
data_lamcts_turbo = get_dataframe('results/Levyturbo2/result200')
data_lamcts_bo = get_dataframe('results/Levybo2/result200')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Levy2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Levyde2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levyturbo2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levybo2/result200' mode='r' encoding='UTF-8'>
