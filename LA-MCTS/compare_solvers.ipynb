# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
def get_dataframe(filename):
    data = pd.read_json(filename, lines=True)
    melted_df = data.melt()
    return melted_df

# %% [markdown]
# ## DE sampling from current samples or from new samples

# %%
de_current_samples = get_dataframe('results/Ackley2_de_rand_1samples/result400')
de_current_samples_wrong = get_dataframe('results/Ackley2_de_rand_1samples_current_samples_wrong/result500')
de_new_samples = get_dataframe('results/Ackley2_de_rand_1samples_sobol/result500')

sns.lineplot(data=de_current_samples, x='variable', y='value', label='current')
sns.lineplot(data=de_current_samples_wrong, x='variable', y='value', label='current (wrong)')
sns.lineplot(data=de_new_samples, x='variable', y='value', label='sobol')

plt.title("Sampling DE/rand [ackley]")
plt.yscale('log')
plt.show()
