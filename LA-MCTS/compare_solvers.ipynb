# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd

# %%
def get_dataframe(filename):
    data = []
    with open(filename, 'r') as file:
        print(file)
        for line in file:
            data.append(json.loads(line))
    n_columns = len(data[0])
    data = pd.DataFrame(data, columns=list(range(1, n_columns + 1, 1)))
    melted_df = pd.melt(data)
    return melted_df

# %%
data_lamcts_de = get_dataframe('results/Ackleyde10/result1400')
data_lamcts_turbo = get_dataframe('results/Ackleyturbo10/result300')
data_lamcts_bo = get_dataframe('results/Ackleybo10/result300')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Ackley10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Ackleyde10/result1400' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleyturbo10/result300' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleybo10/result300' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de = get_dataframe('results/Rosenbrockde10/result1900')
data_lamcts_turbo = get_dataframe('results/Rosenbrockturbo10/result400')
data_lamcts_bo = get_dataframe('results/Rosenbrockbo10/result400')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Rosenbrock10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Rosenbrockde10/result1900' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockturbo10/result400' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockbo10/result400' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de = get_dataframe('results/Levyde10/result800')
data_lamcts_turbo = get_dataframe('results/Levyturbo10/result500')
data_lamcts_bo = get_dataframe('results/Levybo10/result500')
sns.lineplot(data=data_lamcts_de, x='variable', y='value', label='LA-MCTS (DE)')
sns.lineplot(data=data_lamcts_turbo, x='variable', y='value', label='LA-MCTS (TuRBO)')
sns.lineplot(data=data_lamcts_bo, x='variable', y='value', label='LA-MCTS (BO)')

# Set the title and labels for the plot
plt.title('Levy10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Levyde10/result800' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levyturbo10/result500' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levybo10/result500' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de10 = get_dataframe('results/Levyde10/result800')
data_lamcts_de1 = get_dataframe('results/Levyde10_1sample/result500')
sns.lineplot(data=data_lamcts_de10, x='variable', y='value', label='LA-MCTS (DE 10)')
sns.lineplot(data=data_lamcts_de1, x='variable', y='value', label='LA-MCTS (DE 1)')

# Set the title and labels for the plot
plt.title('Levy10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Levyde10/result800' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levyde10_1sample/result500' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de10 = get_dataframe('results/Rosenbrockde10/result1900')
data_lamcts_de1 = get_dataframe('results/Rosenbrockde10_1sample/result500')
sns.lineplot(data=data_lamcts_de10, x='variable', y='value', label='LA-MCTS (DE 10)')
sns.lineplot(data=data_lamcts_de1, x='variable', y='value', label='LA-MCTS (DE 1)')

# Set the title and labels for the plot
plt.title('Rosenbrock10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Rosenbrockde10/result1900' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockde10_1sample/result500' mode='r' encoding='UTF-8'>

# %%
data_lamcts_de10 = get_dataframe('results/Ackleyde10/result1400')
data_lamcts_de1 = get_dataframe('results/Ackleyde10_1sample/result500')
sns.lineplot(data=data_lamcts_de10, x='variable', y='value', label='LA-MCTS (DE 10)')
sns.lineplot(data=data_lamcts_de1, x='variable', y='value', label='LA-MCTS (DE 1)')

# Set the title and labels for the plot
plt.title('Ackley10')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show();
# Out:
# <_io.TextIOWrapper name='results/Ackleyde10/result1400' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleyde10_1sample/result500' mode='r' encoding='UTF-8'>

# %%
ackley_rand = get_dataframe('results/Ackleyde2_1sample/result100')
# ackley_10 = get_dataframe('results/Ackleyde2/result200')
# ackley_10_recomb = get_dataframe('results/recomb/Ackleyde2/result600')
ackley_best = get_dataframe('results/Ackleyde2/result100')


sns.lineplot(data=ackley_rand, x='variable', y='value', label='LA-MCTS (DE - rand)')
# sns.lineplot(data=ackley_10, x='variable', y='value', label='LA-MCTS (DE - 10)')
# sns.lineplot(data=ackley_10_recomb, x='variable', y='value', label='LA-MCTS (DE - 10r)')
sns.lineplot(data=ackley_best, x='variable', y='value', label='LA-MCTS (DE - best)')

plt.title('Ackley2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show()
# Out:
# <_io.TextIOWrapper name='results/Ackleyde2_1sample/result100' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Ackleyde2/result100' mode='r' encoding='UTF-8'>

# %%
rosenbrock_rand = get_dataframe('results/Rosenbrockde2_1sample/result100')
# rosenbrock_10 = get_dataframe('results/Rosenbrockde2/result200')
# rosenbrock_10_recomb = get_dataframe('results/Rosenbrockde2/result600')
rosenbrock_best = get_dataframe('results/Rosenbrockde2/result100')

sns.lineplot(data=rosenbrock_rand, x='variable', y='value', label='LA-MCTS (DE - rand)')
sns.lineplot(data=rosenbrock_best, x='variable', y='value', label='LA-MCTS (DE - best)')
# sns.lineplot(data=rosenbrock_10, x='variable', y='value', label='LA-MCTS (DE - 10)')
# sns.lineplot(data=rosenbrock_10_recomb, x='variable', y='value', label='LA-MCTS (DE - 10r)')

plt.title('Rosenbrock2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show()
# Out:
# <_io.TextIOWrapper name='results/Rosenbrockde2_1sample/result100' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Rosenbrockde2/result100' mode='r' encoding='UTF-8'>

# %%
levy_1 = get_dataframe('results/Levyde2_1sample/result200')
levy_10 = get_dataframe('results/Levyde2/result200')
levy_10_recomb = get_dataframe('results/recomb/Levyde2/result200')

sns.lineplot(data=levy_1, x='variable', y='value', label='LA-MCTS (DE - 1)')
sns.lineplot(data=levy_10, x='variable', y='value', label='LA-MCTS (DE - 10)')
sns.lineplot(data=levy_10, x='variable', y='value', label='LA-MCTS (DE - 10r)')

plt.title('Levy2')
plt.xlabel('# samples')
plt.ylabel('f(x)')
plt.show()
# Out:
# <_io.TextIOWrapper name='results/Levyde2_1sample/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/Levyde2/result200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='results/recomb/Levyde2/result200' mode='r' encoding='UTF-8'>
